# %%
# Write a program to calculate simple interest # all input shoulb be given by the user

# %%
Principal=int(input("Enter the Principal amount: "))
Rate_of_intreset=float(input("Enter the Rate of interest amount: "))
Years=int(input("Enter the number of years: "))
Simple_interest=((Principal*Rate_of_intreset*Years)/100)
print(f"The simple interest is {((Principal*Rate_of_intreset*Years)/100)}")
# Out:
# Enter the Principal amount:  70000
# Enter the Rate of interest amount:  10.70
# Enter the number of years:  3
# The simple interest is 22470.0

# %%
# Write a program to calculate area of circle

# %%
Radius=float(input("Enter the Radius of the circle: "))
Area=3.14*Radius*2
print(f"The Area of the circle is {Area}")
# Out:
# Enter the Radius of the circle:  1
# The Area of the circle i 6.28

# %%
# Write a program to calculate circumference of circle

# %%
Radius=float(input("Enter the Radius of the circumference: "))
Area=3.14*Radius**2
print(f"The Area of the circumference is {Area}")
# Out:
# Enter the Radius of the circumference:  1
# The Area of the circumference i 3.14

# %%
# Write a program to calculate perimeter of square

# %%
s=int(input("Enter the side of the perimeter: "))
Perimeter=4*s
print(f"The Perimeter of the square is {Perimeter}")
# Out:
# Enter the side of the perimeter:  5
# The Perimeter of the square is 20

# %%
# Write a program to calculate area of square

# %%
s=int(input("Enter the length of the side of the Square: "))
Area=s**2
print(f"The Area of the square is {Area}")
# Out:
# Enter the length of the side of the Square:  7
# The Area of the square is 49

# %%
# write a calculator program
