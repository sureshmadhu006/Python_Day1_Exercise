# %%
# Write a program to hours to minutes , user should able to give hours as input

# your Answer
H=int(input("Enter the number of hour: "))
M=Hour*60
print(f"{H} Hour is {M} Minutes")
# Out:
# Enter the number of hour:  1
# 1 Hour is 60 Minutes

# %%
# Write a program to convert centimeter to meter , user shoulb be able to give centimeter as input

# your Answer
CM=int(input("Enter the centerimeter : "))
Meter=CM*0.01
print(f"The meter for above equivalent centimeter is {Meter} ")
# Out:
# Enter the centerimeter :  100
# The meter for above equivalent centimeter is 1.0

# %%
# Write a program to convert miles to Kilometer , user shoulb be able to give miles as input

# your Answer

Miles=int(input("Enter the miles: "))
KM=Miles*0.6
print(f"The equivalent kilometer for miles is  {KM} " )
# Out:
# Enter the miles:  2
# The equivalent kilometer for miles is  1.2

# %%
# Write a program to convert pounds to Kilogram , user shoulb be able to give pounds as input

# your Answer

pound=int(input("Enter the number of pound: "))
kg=pound*0.45
print(f"The equivalent Kilogram for {pound} pound is {kg} kg ")
# Out:
# Enter the number of pound:  100
# The equivalent Kilogram for 100 pound is 45.0 kg

# %%
# Write a program to calculate simple interest # all input shoulb be given by the user

# your Answer

p=int(input("Enter the Principle amount:" ))
i=float(input("Enter the Interest amount:" ))
y=int(input("Enter the Number of years:" ))
si=(p*i*y)/100
print(si)
# Out:
# Enter the Principle amount: 700000
# Enter the Interest amount: 10.7
# Enter the Number of years: 3
# 224699.99999999997

# %%
# Write a program to calculate area of circle

# your Answer

r=float(input("Enter the radius circle:" ))
area=3.14*r**2
print(f"The area of the circle is {area}" )
# Out:
# Enter the radius circle: 1
# The area of the circle is 3.14

# %%
# Write a program to calculate circumference of circle

# your Answer
r=float(input("Enter the radius circle:" ))
c=2*3.14*r
print(f"The circumference of the circle is {c}" )
# Out:
# Enter the radius circle: 1
# The circumference of the circle is 6.28

# %%
# Write a program to calculate perimeter of square

# your Answer

s=float(input("Enter the side length of square:" ))
p=4*s
print(f"The perimeter of square is {p}" )
# Out:
# Enter the side length of square: 2
# The perimeter of square is 8.0

# %%
# Write a program to calculate area of square

# your Answer
s=float(input("Enter the side length of square:" ))
a=s*s
print(f"The area of square is {a}" )
# Out:
# Enter the side length of square: 4
# The area of square is 16.0

# %%
# Write a program to area of traingle

# your Answer

Base=float(input("Enter the Base of the triangle:" ))
Height=float(input("Enter the Height of the triangle:" ))
a=0.2*Base*Height
print(f"The area of the traingle is {a} ")
# Out:
# Enter the Base of the triangle: 10
# Enter the Height of the triangle: 20
# The area of the traingle is 40.0
